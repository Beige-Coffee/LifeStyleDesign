# %%
from selenium.webdriver import Chrome
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import pymongo
from selenium.common.exceptions import NoSuchElementException
from cost_of_living import *
from functools import reduce
import matplotlib.pyplot as plt
# %matplotlib inline
from hidden import debt
from math import cos, sqrt

# %% [markdown]
# ## Write a function to produce cost-of-living in multiple cities

# %%
data = pd.read_excel('data/citydf.xlsx')
data['city'].replace('Washington', "Washington D.C.", inplace=True)

# %%
monthly_constants = {
'Cinema, International Release, 1 Seat' : 2,
'Fitness Club, Monthly Fee for 1 Adult' : 2,
'Basic (Electricity, Heating, Cooling, Water, Garbage) for 915 sq ft Apartment' : 1,
'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)' : 1,
'Gasoline (1 gallon)' : 15,
'Imported Beer (11.2 oz small bottle)' : 10,
'Bottle of Wine (Mid-Range)' : 2,
'Cappuccino (regular)'  : 30,
'Meal, Inexpensive Restaurant' : 8,
'1 Pair of Jeans (Levis 501 Or Similar)' : 1,
'groceries (dollars)': 600
}

def cost_per_city_1B_Center(citydf, monthly_constants):
    for city in citydf.city.unique():
        total = 0
        for item, price in monthly_constants.items():
            if item != 'groceries (dollars)':
                price = float(citydf[(citydf['city']==city) & (citydf['item']==item)].values[0][3]) * price
                total += price
            else:
                total += price
        total += (float(citydf[(citydf['city']==city) & 
                               (citydf['item']=='Apartment (1 bedroom) in City Centre')].values[0][3]))
        result = {
        'city' : city,
        '1_Bed_Center_Total' : total
                  }
        yield result
        
def cost_per_city_3B_Center(citydf, monthly_constants):
    for city in citydf.city.unique():
        total = 0
        for item, price in monthly_constants.items():
            if item != 'groceries (dollars)':
                price = float(citydf[(citydf['city']==city) & (citydf['item']==item)].values[0][3]) * price
                total += price
            else:
                total += price
        total += round((float(citydf[(citydf['city']==city) & 
                               (citydf['item']=='Apartment (3 bedrooms) in City Centre')].values[0][3]) / 3),2)
        result = {
        'city' : city,
        '3_Bed_Center_Total' : total
                  }
        yield result

def cost_per_city_3B_Outside(citydf, monthly_constants):
    for city in citydf.city.unique():
        total = 0
        for item, price in monthly_constants.items():
            if item != 'groceries (dollars)':
                price = float(citydf[(citydf['city']==city) & (citydf['item']==item)].values[0][3]) * price
                total += price
            else:
                total += price
        total += round(((float(citydf[(citydf['city']==city) & 
                               (citydf['item']=='Apartment (3 bedrooms) Outside of Centre')].values[0][3])) / 3),2)
        result = {
        'city' : city,
        '3_Bed_Outside_Total' : total
                  }
        yield result

def cost_per_city_1B_Outside(citydf, monthly_constants):
    for city in citydf.city.unique():
        total = 0
        for item, price in monthly_constants.items():
            if item != 'groceries (dollars)':
                price = float(citydf[(citydf['city']==city) & (citydf['item']==item)].values[0][3]) * price
                total += price
            else:
                total += price
        total += (float(citydf[(citydf['city']==city) & 
                               (citydf['item']=='Apartment (1 bedroom) Outside of Centre')].values[0][3]))
        result = {
        'city' : city,
        '1_Bed_Outside_Total' : total
                  }
        yield result

# %%
def find_cost_of_living(data, monthly_constants):
    B1_center = pd.DataFrame(list(cost_per_city_1B_Center(data, monthly_constants)))
    B3_center = pd.DataFrame(list(cost_per_city_3B_Center(data, monthly_constants)))
    B1_Outside = pd.DataFrame(list(cost_per_city_1B_Outside(data, monthly_constants)))
    B3_Outside = pd.DataFrame(list(cost_per_city_3B_Outside(data, monthly_constants)))
    B1_center.set_index('city', inplace=True)
    B3_center.set_index('city', inplace=True)
    B1_Outside.set_index('city', inplace=True)
    B3_Outside.set_index('city', inplace=True)
    dfs = [B1_center, B3_center, B1_Outside, B3_Outside]
    city_matrix = pd.concat(dfs, axis=1)
    city_matrix['city'] = city_matrix.index
    city_matrix.drop(columns='city', inplace=True)
    return city_matrix

# %%
find_cost_of_living(data, monthly_constants)
# Out:
#                  1_Bed_Center_Total  3_Bed_Center_Total  1_Bed_Outside_Total  \
# city
# Palo-Alto                   4387.48             3127.55              4094.21
# San-Jose                    3714.08             2500.71              3456.40
# Portland                    2864.56             2296.22              2485.55
# Austin                      2969.98             2289.77              2399.66
# Denver                      2907.57             2211.63              2574.14
# San-Diego                   3210.41             2406.10              2804.00
# Washington D.C.             3517.34             2701.31              3064.00
# Boston                      3821.77             2853.61              3136.72
# San-Francisco               4806.91             3329.76              4053.38
# Seattle                     3375.61             2609.09              2866.58
# Atlanta                     2826.20             2212.82              2369.24
# Los-Angeles                 3482.61             2646.62              3036.76
# Chicago                     3078.89             2405.30              2463.50
# New-York                    4646.15             3593.82              3414.25
# Mountain-View               4161.09             2832.76              3674.42
# Santa-Monica                3877.65             3380.75              3464.08
# Cambridge                   2314.90             1854.07              2086.22
# Salt-Lake-City              2440.12             1880.80              2099.88
# Raleigh                     2463.53             1879.52              2220.98
# Nashville                   2872.34             2253.19              2374.51
# Sunnyvale                   4161.60             2806.31              3640.97
# Boulder                     2824.38             2341.05              2562.76
# Irvine                      3353.58             2384.34              3143.25
# Philadelphia                2893.43             2273.30              2368.40
# Dallas                      2590.93             2092.87              2255.06
# Bellevue                    3430.36             2473.14              3130.89
# Charlotte                   2717.21             2051.36              2269.79
# Plano                       2489.02             2043.78              2259.89
# Richmond                    2409.60             1833.64              2187.77
#
#                  3_Bed_Outside_Total
# city
# Palo-Alto                    2871.99
# San-Jose                     2415.23
# Portland                     1980.12
# Austin                       1943.74
# Denver                       1982.24
# San-Diego                    2184.68
# Washington D.C.              2314.06
# Boston                       2316.74
# San-Francisco                2852.41
# Seattle                      2216.39
# Atlanta                      1879.63
# Los-Angeles                  2310.66
# Chicago                      1993.23
# New-York                     2594.11
# Mountain-View                2641.09
# Santa-Monica                 2842.65
# Cambridge                    1725.55
# Salt-Lake-City               1722.83
# Raleigh                      1737.42
# Nashville                    1918.48
# Sunnyvale                    2542.65
# Boulder                      2122.53
# Irvine                       2270.99
# Philadelphia                 1881.41
# Dallas                       1867.09
# Bellevue                     2220.37
# Charlotte                    1797.04
# Plano                        1905.69
# Richmond                     1713.20

# %%
cities = {'New-York': 'New York, New York', 'San-Francisco' : 'San-Francisco, California', 
          'Honolulu' : 'Honolulu, Hawaii', 'Arlington' : 'Arlington, Virgina', 'Anchorage' : 'Anchorage, Alaska',
          'Brooklyn' : 'Brooklyn, New York', 'Santa-Rosa' : 'Santa-Rosa, California', 'Washington' : 'Washington, D.C.',
          'Charleston' : 'Charleston, South Carolina', 'Berkeley' : 'Berkeley, California', 
          'Seattle' : 'Seattle, Washington', 'Jersey-City': 'Jersey City, New Jersey', 
          'Boston' : 'Boston, Massachusetts', 'Oakland' : 'Oakland, California', 'Hartford' : 'Hartford, Connecticut',
          'Philadelphia' : 'Philadelphia, Pennsylvania', 'Albany' : 'Albany, New York','Long-Beach' : 'Long Beach, California', 
          'Irvine' : 'Irvine, California', 'Miami': 'Miami, Florida', 'Los-Angeles' : 'Los Angeles, California',
          'Boulder' : 'Boulder, Colorado', 'Sacramento' : 'Sacramento, California', 'Chicago' : 'Chicago, Illinois',
          'Greenville' : 'Greenville, South Carolina', 'Burlington' : 'Burlington, Vermont', 'San-Jose' : 'San Jose, California',
          'Everett' : 'Everett, Washington', 'Birmingham' : 'Birmingham, Alabama', 'Pittsburgh' : 'Pittsburgh, Pennsylvania',
          'Minneapolis' : 'Minneapolis, Minnesota', 'Baltimore' : 'Baltimore, Maryland', 'Portland' : 'Portland, Oregon',
          'Rochester' : 'Rochester, New York', 'Charlotte' : 'Charlotte, North Carolina',
          'Santa-Barbara' : 'Santa Barbara, California', 'West-Palm-Beach' : 'West Palm Beach, Florida', 
          'Tacoma' : 'Tacoma, Washington', 'Portland-ME' : 'Portland, Maine', 'Bellingham' : 'Bellingham, Washington',
          'San-Diego' : 'San Diego, California', 'Saint-Paul' : 'Saint Paul, Minnesota', 'Atlanta' : 'Atlanta, Georgia',
          'Asheville' : 'Asheville, North Carolina', 'Eugene' : 'Eugene, Oregon', 'Saint-Petersburg' : 'Saint Petersburg, Florida',
          'Buffalo' : 'Buffalo, New York', 'Peoria' : 'Peoria, Illinois', 'Austin' : 'Austin, Texas',
          'Cleveland' : 'Cleveland, Ohio', 'Jacksonville' : 'Jacksonville, Florida', 'Milwaukee' : 'Milwaukee, Wisconsin',
          'Denver' : 'Denver, Colorado', 'Indianapolis' : 'Indianapolis, Indiana', 'Arlington' : 'Arlington, Texas',
          'Ann-Arbor' : 'Ann Arbor, Michigan', 'Raleigh' : 'Raleigh, North Carolina', 'Orlando' : 'Orlando, Florida',
          'Tampa' : 'Tampa, Florida', 'Saint-Louis' : 'Saint Louis, Missouri', 'Nashville' : 'Nashville, Tennessee',
          'Syracuse' : 'Syracuse, New York', 'Salem' : 'Salem, Oregon', 'Kansas-City' : 'Kansas City, Missouri',
          'Spokane' : 'Spokane, Washington', 'Bakersfield' : 'Bakersfield, California', 'Columbus' : 'Columbus, Ohio',
          'Tallahassee' : 'Tallahassee, Florida', 'Memphis' : 'Memphis, Tennessee', 'Las-Vegas' : 'Las Vegas, Nevada',
          'Columbia' : 'Columbia, South Carolina', 'Dallas' : 'Dallas, Texas', 'Detroit': 'Detroit, Michigan', 
          'Phoenix' : 'Phoenix, Arizona', 'Greensboro' : 'Greensboro, North Carolina', 'Richmond' : 'Richmond, Virgina',
          'Cincinnati' : 'Cincinnati, Ohio', 'Fort Worth' : 'Fort Worth, Texas', 'Fresno' : 'Fresno, California',
          'Grand Rapids' : 'Grand Rapids, Michigan', 'Tucson' : 'Tucson, Arizona', 'Fremont' : 'Fremont, California',
          'Riverside' : 'Riverside, California', 'Albuquerque' : 'Albuquerque, New Mexico', 'Tulsa' : 'Tulsa, Oklahoma',
          'Chattanooga' : 'Chattanooga, Tennessee', 'Louisville' : 'Louisville, Kentucky', 'Salt-Lake-City' : 'Salt Lake City, Utah',
          'Houston' : 'Houston, Texas', 'Oklahoma City' : 'Oklahoma-City, Oklahoma', 'Des-Moines' : 'Des Moines, Iowa',
          'Fayetteville' : 'Fayetteville, Arizona', 'Madison' : 'Madison, Wisconsin', 'Wichita' : 'Wichita, Kansas',
          'San-Antonio' : 'San Antonio, Texas', 'Knoxville' : 'Knoxville, Tennessee', 'Vancouver' : 'Vancouver, Washington',
          'Toledo' : 'Toledo, Ohio', 'Boise' : 'Boise, Idaho', 'Reno' : 'Reno, Nevada', 'Little-Rock' : 'Little Rock, Arizona',
          'Huntsville' : 'Huntsville, Alabama', 'El-Paso' : 'El Paso, Texas', 'Lexington' : 'Lexington, Kentucky'}

# %%
city_data = list(scrape_cities(cities.keys()))

# %%
citydf = pd.DataFrame(city_data)

# %%
def get_city_data(city):
    city_data = pd.DataFrame(list(scrape_cities(city)))
    return city_data

# %%
hoboken_data = get_city_data(['Hoboken'])

# %% [markdown]
# ## Write function to standardize prices

# %% [markdown]
# #### Start by finding a city that has missing values. For this example, we'll use Hoboken. We'll then concatenate Hoboken to our other data.

# %%
frames = [citydf, hoboken_data]
result = pd.concat(frames)

# %% [markdown]
# #### Now we'll transpose the DF and move the columns around so that we can work with them.

# %%
import string

# %%
play = result

# %%
play.columns = play.iloc[1]

# %%
play.set_index('city', inplace=True)

# %%
play.replace('?', np.NAN, inplace=True)

# %%
play.dropna(inplace=True)
play['price'] = play['price'].apply(clean_number)

# %%
art = pd.crosstab(index=play['city'], columns=play['item'], values=play['price'], aggfunc=np.mean)

# %%
art.loc[art.isnull().sum(axis=1).astype(np.bool)]
# Out:
# item     1 Pair of Jeans (Levis 501 Or Similar)  \
# city
# Hoboken                                    80.0
#
# item     1 Pair of Men Leather Business Shoes  \
# city
# Hoboken                                 100.0
#
# item     1 Pair of Nike Running Shoes (Mid-Range)  \
# city
# Hoboken                                     96.67
#
# item     1 Summer Dress in a Chain Store (Zara, H&M, ...)  \
# city
# Hoboken                                              50.0
#
# item     1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans)  \
# city
# Hoboken                                                0.1
#
# item     Apartment (1 bedroom) Outside of Centre  \
# city
# Hoboken                                   1875.0
#
# item     Apartment (1 bedroom) in City Centre  \
# city
# Hoboken                               2233.33
#
# item     Apartment (3 bedrooms) Outside of Centre  \
# city
# Hoboken                                    4500.0
#
# item     Apartment (3 bedrooms) in City Centre  Apples (1 lb)  \
# city
# Hoboken                                 4800.0           3.76
#
# item                 ...               Rice (white), (1 lb)  \
# city                 ...
# Hoboken              ...                                4.5
#
# item     Taxi 1 mile (Normal Tariff)  Taxi 1hour Waiting (Normal Tariff)  \
# city
# Hoboken                          5.0                                 NaN
#
# item     Taxi Start (Normal Tariff)  Tennis Court Rent (1 Hour on Weekend)  \
# city
# Hoboken                         6.0                                    NaN
#
# item     Tomato (1 lb)  \
# city
# Hoboken            4.5
#
# item     Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)  \
# city
# Hoboken                                            18500.0
#
# item     Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car)  \
# city
# Hoboken                                            20000.0
#
# item     Water (1.5 liter bottle)  Water (11.2 oz small bottle)
# city
# Hoboken                      2.65                          1.67
#
# [1 rows x 54 columns]

# %%
def clean_number(text):
    """Remove invalid characters from text representation of number and cast to float"""
    valid_chars = ""
    for char in text.strip():
        if char in string.digits + '.':
            valid_chars += char
    return float(valid_chars)

# %%
art
# Out:
# item              1 Pair of Jeans (Levis 501 Or Similar)  \
# city
# Albany                                             46.09
# Albuquerque                                        39.97
# San-Diego                                                    34.03
# San-Francisco                                                43.60
# San-Jose                                                     37.62
# Santa-Barbara                                                24.67
# Santa-Rosa                                                   39.87
# Seattle                                                      42.06
# Spokane                                                      38.00
# Syracuse                                                     26.50
# Tacoma                                                       37.14
# Tallahassee                                                  21.66
# Tampa                                                        38.53
# Toledo                                                       28.78
# Tucson                                                       40.67
# Tulsa                                                        39.25
# Vancouver                                                    43.23
# Washington                                                   37.27
# West-Palm-Beach                                              38.06
# Wichita                                                      39.17
#
# item              1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans)  \
# city
# Albany                                                         0.10
# Albuquerque                                                    0.10
# Anchorage                                                      0.10
# Ann-Arbor                                                      0.10
# Arlington                                                      0.10
# Asheville                                                      0.10
# Atlanta                                                        0.10
# Austin                                                         0.10
# Bakersfield                                                    0.11
# Baltimore                                                      0.10
# Bellingham                                                     0.10
# Berkeley                                                       0.10
# Birmingham                                                     0.04
# Boise                                                          0.10
# Boston                                                         0.10
# Boulder                                                        0.10
# Brooklyn                                                       0.10
# Buffalo                                                        0.10
# Burlington                                                     0.10
# Charleston                                                     0.10
# Charlotte                                                      0.10
# Chattanooga                                                    0.10
# Chicago                                                        0.12
# Cincinnati                                                     0.10
# Cleveland                                                      0.10
# Columbia                                                       0.10
# Columbus                                                       0.14
# Dallas                                                         0.10
# Denver                                                         0.10
# Des-Moines                                                     0.10
# ...                                                             ...
# Raleigh                                                        0.10
# Reno                                                           0.10
# Richmond                                                       0.10
# Riverside                                                      0.10
# Rochester                                                      0.13
# Sacramento                                                     0.11
# Saint-Louis                                                    0.10
# Saint-Paul                                                     0.10
# Saint-Petersburg                                               1.55
# Salem                                                          0.10
# Salt-Lake-City                                                 0.10
# San-Antonio                                                    0.10
# San-Diego                                                      0.10
# San-Francisco                                                  0.10
# San-Jose                                                       0.10
# Santa-Barbara                                                  0.10
# Santa-Rosa                                                     0.10
# Seattle                                                        0.10
# Spokane                                                        0.10
# Syracuse                                                       0.12
# Tacoma                                                         0.10
# Tallahassee                                                    0.10
# Tampa                                                          0.12
# Toledo                                                         0.10
# Tucson                                                         0.11
# Tulsa                                                          0.10
# Vancouver                                                      0.44
# Washington                                                     0.10
# West-Palm-Beach                                                0.10
# Wichita                                                        0.10
#
# item              Apartment (1 bedroom) Outside of Centre  \
# city
# Albany                                             816.27
# Albuquerque                                        708.85
# Anchorage                                          981.67
# Ann-Arbor                                          976.27
# Arlington                                         1670.60
# Asheville                                          888.24
# Atlanta                                           1047.10
# Austin                                            1057.25
# Bakersfield                                        747.27
# Baltimore                                         1048.82
# Bellingham                                         828.64
# Berkeley                                          1986.33
# Birmingham                                         524.05
# Boise                                              743.33
# Boston                                            1732.32
# Boulder                                           1203.50
# Brooklyn                                          1796.88
# Buffalo                                            754.12
# Burlington                                         925.00
# Charleston                                        1065.38
# Charlotte                                          975.53
# Chattanooga                                        761.11
# Chicago                                           1132.98
# Cincinnati                                         662.88
# Cleveland                                          673.68
# Columbia                                           704.17
# Columbus                                           796.82
# Dallas                                             988.22
# Santa-Barbara                                   3350.00           1.75
# Santa-Rosa                                      2629.17           2.29
# Seattle                                         3597.23           2.50
# Spokane                                         1427.78           2.04
# Syracuse                                        2020.00           1.63
# Tacoma                                          2074.18           1.70
# Tallahassee                                     1300.00           2.17
# Tampa                                           2061.11           2.45
# Toledo                                           981.25           1.73
# Tucson                                          1184.93           1.20
# Tulsa                                           1388.21           1.48
# Vancouver                                       3553.31           1.72
# Washington                                      3897.37           3.07
# West-Palm-Beach                                 1999.88           2.13
# Wichita                                         1300.00           1.28
#
# item                          ...               Rice (white), (1 lb)  \
# city                          ...
# Albany                        ...                               1.88
# Albuquerque                   ...                               1.56
# Anchorage                     ...                               3.20
# Ann-Arbor                     ...                               1.36
# Arlington                     ...                               3.23
# Asheville                     ...                               2.44
# Atlanta                       ...                               1.72
# Austin                        ...                               1.30
# Bakersfield                   ...                               1.62
# Baltimore                     ...                               1.72
# Bellingham                    ...                               2.90
# Berkeley                      ...                               2.25
# Birmingham                    ...                               0.59
# Boise                         ...                               1.83
# Boston                        ...                               2.00
# Boulder                       ...                               3.20
# Brooklyn                      ...                               2.27
# Buffalo                       ...                               1.62
# Burlington                    ...                               2.25
# Charleston                    ...                               2.60
# Charlotte                     ...                               1.81
# Chattanooga                   ...                               1.83
# Chicago                       ...                               1.87
# Cincinnati                    ...                               1.72
# Cleveland                     ...                               1.76
# Columbia                      ...                               1.54
# Columbus                      ...                               1.90
# Dallas                        ...                               2.22
# Denver                        ...                               1.50
# Des-Moines                    ...                               1.75
# ...                           ...                                ...
# Raleigh                       ...                               1.72
# Reno                          ...                               1.55
# Richmond                      ...                               1.54
# Riverside                     ...                               1.92
# Rochester                     ...                               1.85
# Sacramento                    ...                               2.20
# Saint-Louis                   ...                               1.88
# Saint-Paul                    ...                               1.00
# Saint-Petersburg              ...                              29.41
# Salem                         ...                               1.59
# Salt-Lake-City                ...                               1.37
# San-Antonio                   ...                               1.11
# San-Diego                     ...                               1.51
# San-Francisco                 ...                               2.53
# San-Jose                      ...                               2.13
# Santa-Barbara                 ...                               2.32
# Santa-Rosa                    ...                               2.00
# Seattle                       ...                               1.84
# Spokane                       ...                               2.75
# Syracuse                      ...                               1.09
# Tacoma                        ...                               2.05
# Tallahassee                   ...                               2.75
# Tampa                         ...                               1.60
# Toledo                        ...                               1.63
# Tucson                        ...                               1.62
# Tulsa                         ...                               1.66
# Vancouver                     ...                               1.87
# Washington                    ...                               1.69
# West-Palm-Beach               ...                               1.80
# Wichita                       ...                               2.00
#
# item              Taxi 1 mile (Normal Tariff)  \
# city
# Albany                                   5.00
# Albuquerque                              2.55
# Anchorage                                2.50
# Ann-Arbor                                3.00
# Arlington                                2.10
# Asheville                                5.00
# Atlanta                                  2.00
# Austin                                   2.70
# Bakersfield                              2.75
# Baltimore                                2.00
# Bellingham                               3.00
# Berkeley                                 4.30
# Birmingham                               2.41
# Boise                                    3.00
# Boston                                   3.30
# Boulder                                  2.25
# Brooklyn                                 2.00
# Buffalo                                  3.50
# Burlington                               2.75
# Charleston                               2.82
# Charlotte                                4.64
# Chattanooga                              2.00
# Chicago                                  2.25
# Cincinnati                               1.64
# Cleveland                                4.00
# Columbia                                 2.50
# Columbus                                 2.83
# Dallas                                   1.80
# Denver                                   2.25
# Des-Moines                               4.25
# ...                                       ...
# Raleigh                                  2.38
# Reno                                     3.06
# Richmond                                 3.00
# Riverside                                1.50
# Rochester                                1.75
# Sacramento                               3.00
# Saint-Louis                              2.00
# Saint-Paul                               2.50
# Saint-Petersburg                        28.97
# Salem                                    2.75
# Salt-Lake-City                           2.85
# San-Antonio                              3.00
# San-Diego                                3.00
# San-Francisco                            2.75
# San-Jose                                 5.00
# Santa-Barbara                            3.00
# Santa-Rosa                               2.50
# Seattle                                  2.70
# Spokane                                  2.90
# Syracuse                                 1.25
# Tacoma                                   2.59
# Tallahassee                              2.50
# Tampa                                    2.20
# Toledo                                   1.00
# Tucson                                   2.35
# Tulsa                                    1.90
# Vancouver                                3.04
# Washington                               2.16
# West-Palm-Beach                          2.88
# Wichita                                  2.00
#
# item              Taxi 1hour Waiting (Normal Tariff)  \
# city
# Albany                                         30.00
# Albuquerque                                    28.40
# Anchorage                                      50.00
# Ann-Arbor                                      24.00
# Arlington                                      23.50
# Asheville                                      18.50
# Atlanta                                        21.00
# Austin                                         29.00
# Bakersfield                                    27.00
# Baltimore                                      25.00
# Bellingham                                     48.00
# Berkeley                                       26.00
# Birmingham                                     30.00
# Boise                                          27.50
# Boston                                         28.00
# Boulder                                        20.00
# Brooklyn                                       30.00
# Buffalo                                        60.00
# Burlington                                     15.00
# Charleston                                     66.00
# Charlotte                                      40.00
# Chattanooga                                    60.00
# Chicago                                        24.00
# Cincinnati                                     18.00
# Cleveland                                      29.00
# Columbia                                       34.25
# Columbus                                       30.00
# Dallas                                         20.00
# Denver                                         22.50
# Des-Moines                                     36.00
# ...                                              ...
# Raleigh                                        16.00
# Reno                                           25.00
# Richmond                                       20.00
# Riverside                                      25.00
# Rochester                                      16.00
# Sacramento                                     29.00
# Saint-Louis                                    21.00
# Saint-Paul                                     24.00
# Saint-Petersburg                              330.00
# Salem                                          30.00
# Salt-Lake-City                                 37.50
# San-Antonio                                    24.00
# San-Diego                                      25.00
# San-Francisco                                  33.00
# San-Jose                                       50.00
# Santa-Barbara                                  30.00
# Santa-Rosa                                     40.00
# Seattle                                        30.00
# Spokane                                        50.00
# Syracuse                                       25.00
# Tacoma                                         30.00
# Tallahassee                                    24.60
# Tampa                                          18.00
# Toledo                                          6.00
# Tucson                                         24.00
# Tulsa                                          30.00
# ...
# San-Jose                                          15.00           1.70
# Santa-Barbara                                     15.00           1.43
# Santa-Rosa                                        55.00           2.85
# Seattle                                           29.10           2.15
# Spokane                                           20.00           1.33
# Syracuse                                          22.50           1.35
# Tacoma                                            20.00           2.60
# Tallahassee                                        4.98           1.99
# Tampa                                             13.75           2.08
# Toledo                                            31.33           1.15
# Tucson                                            23.00           1.21
# Tulsa                                              2.67           1.91
# Riverside                                                   19000.0
# Rochester                                                   23000.0
# Sacramento                                                  22000.0
# Saint-Louis                                                 20402.5
# Saint-Paul                                                  22447.5
# Saint-Petersburg                                          1000000.0
# Salem                                                       22857.5
# Salt-Lake-City                                              19895.0
# San-Antonio                                                 22375.0
# San-Diego                                                   23000.0
# San-Francisco                                               22000.0
# San-Jose                                                    19895.0
# Santa-Barbara                                               21000.0
# Santa-Rosa                                                  24812.5
# Seattle                                                     22000.0
# Spokane                                                     26000.0
# Syracuse                                                    20000.0
# Tacoma                                                      24537.0
# Tallahassee                                                 21991.5
# Tampa                                                       21500.0
# Toledo                                                      20250.0
# Tucson                                                      22488.5
# Tulsa                                                       20839.0
# Vancouver                                                   25440.0
# Washington                                                  21500.0
# West-Palm-Beach                                             25997.5
# Wichita                                                     23000.0
#
# item              Water (1.5 liter bottle)  Water (11.2 oz small bottle)
# city
# Albany                                1.92                          1.78
# Albuquerque                           2.19                          1.48
# Anchorage                             2.17                          1.86
# Ann-Arbor                             1.75                          1.22
# Arlington                             1.75                          1.75
# Asheville                             1.75                          1.46
# Atlanta                               1.82                          1.60
# Austin                                1.45                          1.69
# Bakersfield                           1.70                          1.30
# Baltimore                             1.79                          1.38
# Bellingham                            1.47                          1.75
# Berkeley                              1.83                          1.79
# Birmingham                            1.05                          1.12
# Boise                                 1.42                          1.51
# Boston                                1.57                          1.66
# Boulder                               2.19                          1.62
# Brooklyn                              1.75                          1.62
# Buffalo                               1.37                          1.44
# Burlington                            2.33                          1.25
# Charleston                            3.00                          1.43
# Charlotte                             1.85                          1.37
# Chattanooga                           1.88                          1.29
# Chicago                               2.06                          1.83
# Cincinnati                            2.00                          1.22
# Cleveland                             1.72                          1.30
# Columbia                              1.83                          1.26
# Columbus                              1.76                          1.18
# Dallas                                1.42                          1.26
# Denver                                2.26                          1.37
# Des-Moines                            2.00                          1.68
# ...                                    ...                           ...
# Raleigh                               1.59                          1.46
# Reno                                  1.35                          1.23
# Richmond                              1.79                          1.59
# Riverside                             1.44                          1.59
# Rochester                             2.17                          1.50
# Sacramento                            1.61                          1.48
# Saint-Louis                           1.54                          1.39
# Saint-Paul                            1.83                          1.60
# Saint-Petersburg                     44.33                         35.91
# Salem                                 1.70                          1.68
# Salt-Lake-City                        1.46                          1.36
# San-Antonio                           1.45                          1.40
# San-Diego                             1.93                          1.69
# San-Francisco                         2.14                          1.80
# San-Jose                              1.45                          1.64
# Santa-Barbara                         1.30                          1.67
# Santa-Rosa                            1.25                          1.55
# Seattle                               2.07                          1.58
# Spokane                               2.54                          1.57
# Syracuse                              2.16                          1.41
# Tacoma                                2.00                          1.22
# Tallahassee                           1.75                          1.31
# Tampa                                 1.30                          1.56
# Toledo                                1.73                          1.21
# Tucson                                1.35                          1.27
# Tulsa                                 2.09                          1.39
# Vancouver                             2.29                          2.06
# Washington                            2.56                          1.76
# West-Palm-Beach                       1.69                          1.29
# Wichita                               2.10                          1.33
#
# [101 rows x 54 columns]

# %%
art.shape
# Out:
# (101, 54)
